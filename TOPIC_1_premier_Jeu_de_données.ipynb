# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_HACKATHON\hackathon_3333_final.csv')

print(df.head(10).to_string())



print(df.shape)          
print(df.dtypes)         
print(df.describe())    
print(df.isnull().sum())
# Out:
#     user_id             name   age                                      interests                                                                                                                                                                                                                                                                                                                activity_log main_interest  activity_count  has_tech_interest  interest_technology  interest_music  interest_fitness  interest_reading  interest_cooking  interest_travel  _is_duplicate
# ...
